# %%
import requests
from pprint import pprint
import pandas as pd
from datetime import datetime
import concurrent.futures

# %%
#Base URL for API call
base_url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/"

fatal_cases = []

# writing a for loop for all 50 states and from 2018 - 2021 so it doesn't exceed API call limit
for state in range(50):
    for y_since_2018 in range(4):
        response  = requests.get(base_url + f"GetCaseList?states={state}&fromYear={2018 + y_since_2018}&toYear={2018 + y_since_2018}&minNumOfVehicles=0&maxNumOfVehicles=10&format=json")
        data = response.json()
        fatal_cases += data["Results"][0]

# %%
df = pd.DataFrame(fatal_cases)
df.head()
# Out:
#         CountyName                   CrashDate  Fatals  Peds  Persons  \
# 0  TALLADEGA (121)  /Date(1515150000000-0500)/       1     0        1
# 1     WALKER (127)  /Date(1515390480000-0500)/       2     0        2
# 2     CHILTON (21)  /Date(1515469800000-0500)/       1     0        2
# 3      BALDWIN (3)  /Date(1515520920000-0500)/       1     0        2
# 4   JEFFERSON (73)  /Date(1516363740000-0500)/       1     0        2
#
#    St_Case  State StateName  TotalVehicles
# 0    10001      1   Alabama              2
# 1    10002      1   Alabama              1
# 2    10003      1   Alabama              2
# 3    10004      1   Alabama              1
# 4    10005      1   Alabama              2

# %%
#filter out the problematic dates
df_filtered = df[df["CrashDate"] != "/Date(-62135578800000-0500)/"]
df_filtered.loc[:, "CrashDate"] = df_filtered["CrashDate"].apply(lambda x: datetime.fromtimestamp(int(x[6:19])/1000))

df_filtered = df_filtered.sort_values(by = "CrashDate")

df_filtered = df_filtered.reset_index(drop=True)

df_filtered.head()
# Out:
# /var/folders/p1/sd0bq34d5xx6bcr_yjx4qcc40000gn/T/ipykernel_77890/2788994974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:, "CrashDate"] = df_filtered["CrashDate"].apply(lambda x: datetime.fromtimestamp(int(x[6:19])/1000))
#        CountyName           CrashDate  Fatals  Peds  Persons  St_Case  State  \
# 0  RIVERSIDE (65) 2017-12-31 23:01:00       1     0        4    63463      6
# 1       LAKE (69) 2017-12-31 23:15:00       1     0        1   120156     12
# 2    DOUGLAS (55) 2017-12-31 23:20:00       1     0        2   310001     31
# 3     GREGG (183) 2017-12-31 23:22:00       1     0        1   480010     48
# 4    DALLAS (113) 2017-12-31 23:30:00       2     0        2   480006     48
#
#     StateName  TotalVehicles
# 0  California              2
# 1     Florida              1
# 2    Nebraska              2
# 3       Texas              1
# 4       Texas              2

# %%
# list to hold crash case details
crash_details = []

def worker(lower, upper):
    for idx in range(lower, upper):
        row = df_filtered.iloc[idx]
        state_case = row["St_Case"]
        state_case_year = row["CrashDate"].strftime('%Y')  
        state_number = row["State"]

        # Information displaying throughout the pulling of data
        if idx % 500 == 0:
            print(f"Starting the {idx}th run")

        try:
            base_url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/"
            response = requests.get(base_url + f"GetCaseDetails?stateCase={state_case}&caseYear={state_case_year}&state={state_number}&format=json")
            data = response.json()

            # Info that we need to pull from the JSON API
            crash_result = data["Results"][0][0]["CrashResultSet"]
            case_year = crash_result["CaseYear"]
            day_week = crash_result["DAY_WEEK"]
            day_week_name = crash_result["DAY_WEEKNAME"]
            hour = crash_result["HOUR"]
            latitude = crash_result["LATITUDE"]
            longitude = crash_result["LONGITUD"]
            month_name = crash_result["MonthName"]
            route_name = crash_result["ROUTENAME"]
            state_name = crash_result["STATENAME"]
            st_case = crash_result["ST_CASE"]

            # Add the data to the crash_details list
            crash_details.append({
                "CaseYear": case_year,
                "DAY_WEEK": day_week,
                "DAY_WEEKNAME": day_week_name,
                "HOUR": hour,
                "LATITUDE": latitude,
                "LONGITUD": longitude,
                "MonthName": month_name,
                "ROUTENAME": route_name,
                "STATENAME": state_name,
                "ST_CASE": st_case
            })
            
        except Exception as e:
            print(f"Error on index {idx}: {e}")

# Define the number of workers and calculate the range of indices they will process
num_workers = 10
total_rows = len(df_filtered)
chunk_size = total_rows // num_workers
ranges = [(i * chunk_size, (i + 1) * chunk_size) for i in range(num_workers)]
ranges[-1] = (ranges[-1][0], total_rows)  # Adjust last range to include all rows

# Execute the worker function using concurrent threads
with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
    futures = [executor.submit(worker, lower, upper) for lower, upper in ranges]
    concurrent.futures.wait(futures)

# After all threads complete, the crash_details list will contain the required information. This data can be halted and exported without fully completing the run.
# Out:
# Starting the 0th run
# Starting the 53500th run
# Starting the 107000th run
# Starting the 13500th run
# Starting the 67000th run
# Starting the 120500th run
# Starting the 27000th run
# Starting the 80500th run
# Starting the 40500th run
# Starting the 94000th run
# Starting the 500th run
# Starting the 54000th run
# Starting the 14000th run
# Starting the 107500th run
# Starting the 67500th run
# Starting the 27500th run
# Starting the 121000th run
# Starting the 81000th run
# Starting the 41000th run
# Starting the 94500th run
# Starting the 1000th run
# Starting the 54500th run
# Starting the 14500th run
# Starting the 108000th run
# Starting the 68000th run
# Starting the 28000th run
# Starting the 121500th run
# Starting the 81500th run
# Starting the 41500th run
# Starting the 1500th run
# Starting the 95000th run
# Starting the 55000th run
# Starting the 15000th run
# Starting the 108500th run
# Starting the 68500th run
# Starting the 28500th run
# Starting the 82000th run
# Starting the 122000th run
# Starting the 42000th run
# Starting the 2000th run
# Starting the 95500th run
# Starting the 55500th run
# Starting the 15500th run
# Starting the 29000th run
# Starting the 69000th run
# Starting the 109000th run
# Starting the 82500th run
# Starting the 42500th run
# Starting the 122500th run
# Starting the 2500th run
# Starting the 56000th run
# Starting the 96000th run
# Starting the 16000th run
# Starting the 29500th run
# Starting the 69500th run
# Starting the 109500th run
# Starting the 83000th run
# Starting the 43000th run
# Starting the 3000th run
# Starting the 123000th run
# Starting the 56500th run
# Starting the 96500th run
# Starting the 16500th run
# Starting the 30000th run
# Starting the 70000th run
# Starting the 110000th run
# Starting the 43500th run
# Starting the 83500th run
# Starting the 3500th run
# Starting the 123500th run
# Starting the 57000th run
# Starting the 17000th run
# Starting the 97000th run
# Starting the 30500th run
# Starting the 70500th run
# Starting the 44000th run
# Starting the 84000th run
# Starting the 110500th run
# Starting the 4000th run
# Starting the 57500th run
# Starting the 17500th run
# Starting the 124000th run
# Starting the 97500th run
# Starting the 31000th run
# Starting the 71000th run
# Starting the 44500th run
# Starting the 4500th run
# Starting the 84500th run
# Starting the 111000th run
# Starting the 58000th run
# Starting the 18000th run
# Starting the 124500th run
# Starting the 98000th run
# Starting the 31500th run
# Starting the 71500th run
# Starting the 45000th run
# Starting the 5000th run
# Starting the 85000th run
# Starting the 111500th run
# Starting the 18500th run
# Starting the 58500th run
# Starting the 125000th run
# Starting the 32000th run
# Starting the 98500th run
# Starting the 72000th run
# Starting the 45500th run
# Starting the 5500th run
# Starting the 85500th run
# Starting the 19000th run
# Starting the 59000th run
# Starting the 112000th run
# Starting the 32500th run
# Starting the 125500th run
# Starting the 99000th run
# Starting the 72500th run
# Starting the 46000th run
# Starting the 6000th run
# Starting the 86000th run
# Starting the 19500th run
# Starting the 59500th run
# Starting the 112500th run
# Starting the 33000th run
# Starting the 126000th run
# Starting the 73000th run
# Starting the 99500th run
# Starting the 46500th run
# Starting the 6500th run
# Starting the 86500th run
# Starting the 20000th run
# Starting the 60000th run
# Starting the 113000th run
# Starting the 33500th run
# Starting the 126500th run
# Starting the 73500th run
# Starting the 7000th run
# Starting the 47000th run
# Starting the 100000th run
# Starting the 20500th run
# Starting the 87000th run
# Starting the 60500th run
# Starting the 34000th run
# Starting the 113500th run
# Starting the 7500th run
# Starting the 47500th run
# Starting the 74000th run
# Starting the 127000th run
# Starting the 100500th run
# Starting the 21000th run
# Starting the 87500th run
# Starting the 61000th run
# Starting the 34500th run
# Starting the 114000th run
# Starting the 8000th run
# Starting the 48000th run
# Starting the 74500th run
# Starting the 127500th run
# Starting the 21500th run
# Starting the 101000th run
# Starting the 88000th run
# Starting the 61500th run
# Starting the 35000th run
# Starting the 114500th run
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 60
#      59 futures = [executor.submit(worker, lower, upper) for lower, upper in ranges]
# ---> 60 concurrent.futures.wait(futures)
#
# File ~/anaconda3/envs/dev/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#
# File ~/anaconda3/envs/dev/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/dev/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 58
#      55 ranges[-1] = (ranges[-1][0], total_rows)  # Adjust last range to include all rows
#      57 # Execute the worker function using concurrent threads
# ---> 58 with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
#      59     futures = [executor.submit(worker, lower, upper) for lower, upper in ranges]
#      60     concurrent.futures.wait(futures)
#
# File ~/anaconda3/envs/dev/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/anaconda3/envs/dev/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/anaconda3/envs/dev/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/dev/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Starting the 8500th run
# Starting the 48500th run
# Starting the 75000th run

# %%
df = pd.DataFrame(crash_details)

# filename for the CSV file
filename = 'crash_details.csv'

# Save DataFrame to CSV file, w/out including the index
df.to_csv(filename, index=False)
