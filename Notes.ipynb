# %%
import requests
import json

# URL from which to fetch the JSON data
url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseDetails?stateCase=10003&caseYear=2014&state=1&format=json"

# Make a GET request to fetch the JSON data
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Load JSON data from the response
    data = response.json()
    
    # Pretty print the JSON data
    pretty_data = json.dumps(data, indent=4)
    print(pretty_data)
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# {
#     "Count": 1,
#     "Message": "Results returned successfully",
#     "Results": [
#         [
#             {
#                 "CrashResultSet": {
#                     "ARR_HOUR": "3",
#                     "ARR_HOURNAME": "3:00am-3:59am",
#                     "ARR_MIN": "10",
#                     "ARR_MINNAME": "10",
#                     "CEvents": [
#                         {
#                             "AOI1": "12",
#                             "AOI1NAME": "12 Clock Point",
#                             "AOI2": "8",
#                             "AOI2NAME": "8 Clock Point",
#                             "CaseYear": "2014",
#                             "EVENTNUM": "1",
#                             "SOE": "12",
#                             "SOENAME": "Motor Vehicle In-Transport ",
#                             "STATE": "1",
#                             "STATENAME": "Alabama",
#                             "ST_CASE": "10003",
#                             "VNUMBER1": "1",
#                             "VNUMBER2": "2"
#                         },
#                         {
#                             "AOI1": "55",
#                             "AOI1NAME": "Non-Harmful Event",
#                             "AOI2": "55",
#                             "AOI2NAME": "Non-Harmful Event",
#                             "CaseYear": "2014",
#                             "EVENTNUM": "2",
#                             "SOE": "63",
#                             "SOENAME": "Ran Off Roadway - Right",
#                             "STATE": "1",
#                             "STATENAME": "Alabama",
#                             "ST_CASE": "10003",
#                             "VNUMBER1": "2",
#                             "VNUMBER2": "5555"
#                         },
#                         {
#                             "AOI1": "98",
#                             "AOI1NAME": "Not Reported",
#                             "AOI2": "77",
#                             "AOI2NAME": "Not a Motor Vehicle",
#                             "CaseYear": "2014",
#                             "EVENTNUM": "3",
#                             "SOE": "30",
#                             "SOENAME": "Utility Pole/Light Support",
#                             "STATE": "1",
#                             "STATENAME": "Alabama",
#                             "ST_CASE": "10003",
#                             "VNUMBER1": "2",
#                             "VNUMBER2": "9999"
#                         }
#                     ],
#                     "CF1": "0",
#                     "CF1NAME": "None",
#                     "CF2": "0",
#                     "CF2NAME": "None",
#                     "CF3": "0",
#                     "CF3NAME": "None",
#                     "CITY": "3050",
#                     "CITYNAME": "TUSCALOOSA",
#                     "COUNTY": "125",
#                     "COUNTYNAME": "TUSCALOOSA (125)",
#                     "CaseYear": "2014",
#                     "CrashRFs": null,
#                     "DAY": "1",
#                     "DAY_WEEK": "4",
#                     "DAY_WEEKNAME": "Wednesday",
#                     "DRUNK_DR": "0",
#                     "FATALS": "2",
#                     "FUNC_SYS": null,
#                     "FUNC_SYSNAME": null,
#                     "HARM_EV": "12",
#                     "HARM_EVNAME": "Motor Vehicle In-Transport ",
#                     "HOSP_HR": "99",
#                     "HOSP_HRNAME": "Unknown",
#                     "HOSP_MN": "99",
#                     "HOSP_MNNAME": "Unknown EMS Hospital Arrival Time",
#                     "HOUR": "3",
#                     "HOURNAME": "3:00am-3:59am",
#                     "LATITUDE": "33.19717222",
#                     "LATITUDENAME": "33.19717222",
#                     "LGT_COND": "3",
#                     "LGT_CONDNAME": "Dark - Lighted",
#                     "LONGITUD": "-87.525911110",
#                     "LONGITUDNAME": "-87.525911110",
#                     "MAN_COLL": "6",
#                     "MAN_COLLNAME": "Angle ",
#                     "MILEPT": "0",
#                     "MILEPTNAME": "None",
#                     "MINUTE": "7",
#                     "MINUTENAME": "7",
#                     "MONTH": "1",
#                     "MonthName": "January",
#                     "NHS": "1",
#                     "NHSNAME": "This section IS ON the NHS",
#                     "NMDrugs": null,
#                     "NMPersonRF": null,
#                     "NMRace": null,
#                     "NOT_HOUR": "99",
#                     "NOT_HOURNAME": "Unknown",
#                     "NOT_MIN": "99",
#                     "NOT_MINNAME": "Unknown",
#                     "NPersons": null,
#                     "NmCrashes": null,
#                     "NmDistract": null,
#                     "NmImpairs": null,
#                     "NmPriors": null,
#                     "PEDS": "0",
#                     "PERMVIT": "7",
#                     "PERNOTMVIT": "0",
#                     "PERSONS": "7",
#                     "PVH_INVL": "0",
#                     "ParkWorks": null,
#                     "PbTypes": null,
#                     "RAIL": "0000000",
#                     "RAILNAME": "Not Applicable",
#                     "RD_OWNER": null,
#                     "RD_OWNERNAME": null,
#                     "RELJCT1": "0",
#                     "RELJCT1NAME": "No",
#                     "RELJCT2": "2",
#                     "RELJCT2NAME": "Intersection",
#                     "REL_ROAD": "1",
#                     "REL_ROADNAME": "On Roadway",
#                     "ROAD_FNC": "13",
#                     "ROAD_FNCNAME": "Urban-Other Principal Arterial",
#                     "ROUTE": "2",
#                     "ROUTENAME": "U.S. Highway",
#                     "RUR_URB": null,
#                     "RUR_URBNAME": null,
#                     "SCH_BUS": "0",
#                     "SCH_BUSNAME": "No",
#                     "SP_JUR": "0",
#                     "SP_JURNAME": "No Special Jurisdiction",
#                     "STATENAME": "Alabama",
#                     "ST_CASE": "10003",
#                     "SafetyEQs": null,
#                     "State": "1",
#                     "TWAY_ID": "US-SR 6",
#                     "TWAY_ID2": "VERTERAN'S MEMORIAL PKWY",
#                     "TYP_INT": "2",
#                     "TYP_INTNAME": "Four-Way Intersection",
#                     "VE_FORMS": "2",
#                     "VE_TOTAL": "2",
#                     "Vehicles": [
#                         {
#                             "ACC_TYPE": "88",
#                             "ACC_TYPENAME": "L88-Intersecting Paths-Straight Paths-Striking from the Left",
#                             "ADS_ENG": null,
#                             "ADS_ENGName": null,
#                             "ADS_LEV": null,
#                             "ADS_LEVName": null,
#                             "ADS_PRES": null,
#                             "ADS_PRESName": null,
#                             "BODY_TYP": "4",
#                             "BODY_TYPNAME": "4-door sedan, hardtop",
#                             "BUS_USE": "0",
#                             "BUS_USENAME": "Not a Bus",
#                             "CARGO_BT": "0",
#                             "CARGO_BTNAME": "Not Applicable (N/A)",
#                             "CDL_STAT": "0",
#                             "CDL_STATNAME": "No (CDL)",
#                             "CaseYear": "2014",
#                             "CrashDate": null,
#                             "DAY": "1",
#                             "DEATHS": "0",
#                             "DEFORMED": "6",
#                             "DEFORMEDNAME": "Disabling Damage",
#                             "DR_DRINK": "0",
#                             "DR_DRINKNAME": "No",
#                             "DR_HGT": "999",
#                             "DR_PRES": "1",
#                             "DR_PRESNAME": "Yes",
#                             "DR_SF1": "39",
#                             "DR_SF1NAME": "Failure to Obey Actual Traffic Sign,Traffic Control Devices or Traffic Officers;Failure to Obey Safety Zone Traffic Laws",
#                             "DR_SF2": "0",
#                             "DR_SF2NAME": "None",
#                             "DR_SF3": "0",
#                             "DR_SF3NAME": "None",
#                             "DR_SF4": "0",
#                             "DR_SF4NAME": "None",
#                             "DR_WGT": "999",
#                             "DR_WGTNAME": "Unknown",
#                             "DR_ZIP": "35404",
#                             "DR_ZIPNAME": "35404",
#                             "Damages": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "1",
#                                     "DAMAGENAME": "1 Clock Value",
#                                     "MDAREAS": "1",
#                                     "MDAREASNAME": "1 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 },
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "2",
#                                     "DAMAGENAME": "2 Clock Value",
#                                     "MDAREAS": "2",
#                                     "MDAREASNAME": "2 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 },
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "3",
#                                     "DAMAGENAME": "3 Clock Value",
#                                     "MDAREAS": "3",
#                                     "MDAREASNAME": "3 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 },
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "4",
#                                     "DAMAGENAME": "4 Clock Value",
#                                     "MDAREAS": "4",
#                                     "MDAREASNAME": "4 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 },
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "11",
#                                     "DAMAGENAME": "11 Clock Value",
#                                     "MDAREAS": "11",
#                                     "MDAREASNAME": "11 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 },
#                                 {
#                                     "CaseYear": "2014",
#                                     "DAMAGE": "12",
#                                     "DAMAGENAME": "12 Clock Value",
#                                     "MDAREAS": "12",
#                                     "MDAREASNAME": "12 Clock Value",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 }
#                             ],
#                             "Distractions": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "DRDISTRACT": "0",
#                                     "DRDISTRACTNAME": "Not Distracted",
#                                     "MDRDSTRD": "0",
#                                     "MDRDSTRDNAME": "Not Distracted",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 }
#                             ],
#                             "DrImpairs": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "DRIMPAIR": "99",
#                                     "DRIMPAIRNAME": "Unknown if Impaired",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 }
#                             ],
#                             "DrierRFs": [],
#                             "EMER_USE": "0",
#                             "EMER_USENAME": "Not Applicable",
#                             "FIRE_EXP": "0",
#                             "FIRE_EXPNAME": "No or Not Reported",
#                             "FIRST_MO": "0",
#                             "FIRST_MONAME": "No Record",
#                             "FIRST_YR": "0",
#                             "FIRST_YRNAME": "No Record",
#                             "Factors": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "MFACTOR": "0",
#                                     "MFACTORNAME": "None",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEHICLECC": "0",
#                                     "VEHICLECCNAME": "None",
#                                     "VEH_NO": "1"
#                                 }
#                             ],
#                             "GVWR": "0",
#                             "GVWRNAME": "Not Applicable",
#                             "GVWR_FROM": null,
#                             "GVWR_FROMNAME": null,
#                             "GVWR_TO": null,
#                             "GVWR_TONAME": null,
#                             "HARM_EV": "12",
#                             "HARM_EVNAME": "Motor Vehicle In-Transport ",
#                             "HAZ_CNO": "0",
#                             "HAZ_CNONAME": "Not Applicable",
#                             "HAZ_ID": "0",
#                             "HAZ_IDNAME": "Not Applicable",
#                             "HAZ_INV": "1",
#                             "HAZ_INVNAME": "No",
#                             "HAZ_PLAC": "0",
#                             "HAZ_PLACNAME": "Not Applicable",
#                             "HAZ_REL": "0",
#                             "HAZ_RELNAME": "Not Applicable",
#                             "HIT_RUN": "1",
#                             "HIT_RUNNAME": "Yes",
#                             "HOUR": "3",
#                             "HOURNAME": "3:00am-3:59am",
#                             "ICFINALBODY": null,
#                             "ICFINALBODYNAME": null,
#                             "IMPACT1": "12",
#                             "IMPACT1NAME": "12 Clock Point",
#                             "IMPACT2": null,
#                             "IMPACT2NAME": null,
#                             "J_KNIFE": "0",
#                             "J_KNIFENAME": "Not an Articulated Vehicle",
#                             "LAST_MO": "0",
#                             "LAST_MONAME": "No Record",
#                             "LAST_YR": "0",
#                             "LAST_YRNAME": "No Record",
#                             "L_COMPL": "0",
#                             "L_COMPLNAME": "Not licensed",
#                             "L_ENDORS": "0",
#                             "L_ENDORSNAME": "No Endorsements required for this vehicle",
#                             "L_RESTRI": "0",
#                             "L_RESTRINAME": "No Restrictions or Not Applicable",
#                             "L_STATE": "1",
#                             "L_STATENAME": "Alabama",
#                             "L_STATUS": "0",
#                             "L_STATUSNAME": "Not licensed",
#                             "L_TYPE": "0",
#                             "L_TYPENAME": "Not Licensed",
#                             "MAKE": "20",
#                             "MAKENAME": "Chevrolet",
#                             "MAK_MOD": "20037",
#                             "MAK_MODNAME": "Chevrolet Malibu/Malibu Maxx",
#                             "MAN_COLL": "6",
#                             "MAN_COLLNAME": "Angle ",
#                             "MCARR_I1": "0",
#                             "MCARR_I1NAME": "Not Applicable",
#                             "MCARR_I2": "000000000",
#                             "MCARR_I2NAME": "Not Applicable",
#                             "MCARR_ID": "00000000000",
#                             "MCARR_IDNAME": "Not Applicable",
#                             "MINUTE": "7",
#                             "MINUTENAME": "7",
#                             "MODEL": "37",
#                             "MODELNAME": "Malibu/Malibu Maxx",
#                             "MOD_YEAR": "2004",
#                             "MOD_YEARNAME": "2004",
#                             "MONTH": "1",
#                             "M_HARM": "12",
#                             "M_HARMNAME": "Motor Vehicle In-Transport ",
#                             "Maneuvers": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "MANEUVER": "0",
#                                     "MANEUVERNAME": "Driver Did Not Maneuver to Avoid",
#                                     "MDRMANAV": "0",
#                                     "MDRMANAVNAME": "Driver Did Not Maneuver to Avoid",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "1"
#                                 }
#                             ],
#                             "MonthName": "January",
#                             "NCSABODY_TYP": null,
#                             "NCSABODY_TYPNAME": null,
#                             "NCSAMAKE": null,
#                             "NCSAMAKENAME": null,
#                             "NCSAMODEL": null,
#                             "NCSAMODELNAME": null,
#                             "NUMOCCS": "4",
#                             "NUMOCCSNAME": "04",
#                             "OWNER": "2",
#                             "OWNERNAME": "Driver (in this crash) Not Registered Owner (Other Private Owner Listed)",
#                             "PCRASH4NAME": "Tracking",
#                             "PCRASH5": "1",
#                             "PCRASH5NAME": "Stayed in original travel lane",
#                             "PREV_ACC": "0",
#                             "PREV_ACCNAME": "None",
#                             "PREV_DWI": "0",
#                             "PREV_DWINAME": "None",
#                             "PREV_OTH": "0",
#                             "PREV_OTHNAME": "None",
#                             "PREV_SPD": "0",
#                             "PREV_SPDNAME": "None",
#                             "PREV_SUS": "0",
#                             "PREV_SUS1": null,
#                             "PREV_SUS1NAME": null,
#                             "PREV_SUS2": null,
#                             "PREV_SUS2NAME": null,
#                             "PREV_SUS3": null,
#                             "PREV_SUS3NAME": null,
#                             "PREV_SUSNAME": "None",
#                             "P_CRASH1": "1",
#                             "P_CRASH1NAME": "Going Straight",
#                             "P_CRASH2": "17",
#                             "P_CRASH2NAME": "Crossing over (passing through) intersection",
#                             "P_CRASH3": "1",
#                             "P_CRASH3NAME": "No Avoidance Maneuver",
#                             "P_CRASH4": null,
#                             "Persons": [
#                                 {
#                                     "AGE": "22",
#                                     "AGENAME": "22 Years",
#                                     "AIR_BAG": "20",
#                                     "AIR_BAGNAME": "Not Deployed",
#                                     "ALC_DET": "9",
#                                     "ALC_DETNAME": "Not Reported",
#                                     "ALC_RES": "96",
#                                     "ALC_RESNAME": "Test Not Given",
#                                     "ALC_STATUS": "0",
#                                     "ALC_STATUSNAME": "Test Not Given",
#                                     "ATST_TYP": "0",
#                                     "ATST_TYPNAME": "Test Not Given",
#                                     "BODY_TYP": "4",
#                                     "BODY_TYPNAME": "4-door sedan, hardtop",
#                                     "CERT_NO": "************",
#                                     "COUNTY": "125",
#                                     "COUNTYNAME": "TUSCALOOSA (125)",
#                                     "CaseYear": "2014",
#                                     "DAY": "1",
#                                     "DEATH_DA": "88",
#                                     "DEATH_DANAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_HR": "88",
#                                     "DEATH_HRNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MN": "88",
#                                     "DEATH_MNNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MO": "88",
#                                     "DEATH_MONAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_TM": "8888",
#                                     "DEATH_TMNAME": "Not Applicable (Non-fatal",
#                                     "DEATH_YR": "8888",
#                                     "DEATH_YRNAME": "Not Applicable (Non-fatal)",
#                                     "DOA": "0",
#                                     "DOANAME": "Not Applicable",
#                                     "DRINKING": "9",
#                                     "DRINKINGNAME": "Unknown (Police Reported)",
#                                     "DRUGRES1": "0",
#                                     "DRUGRES1NAME": "Test Not Given",
#                                     "DRUGRES2": "0",
#                                     "DRUGRES2NAME": "Test Not Given",
#                                     "DRUGRES3": "0",
#                                     "DRUGRES3NAME": "Test Not Given",
#                                     "DRUGS": "9",
#                                     "DRUGSNAME": "Unknown",
#                                     "DRUGTST1": "0",
#                                     "DRUGTST1NAME": "Test Not Given",
#                                     "DRUGTST2": "0",
#                                     "DRUGTST2NAME": "Test Not Given",
#                                     "DRUGTST3": "0",
#                                     "DRUGTST3NAME": "Test Not Given",
#                                     "DRUG_DET": "8",
#                                     "DRUG_DETNAME": "Not Reported",
#                                     "DSTATUS": "0",
#                                     "DSTATUSNAME": "Test Not Given",
#                                     "EJECTION": "0",
#                                     "EJECTIONNAME": "Not Ejected",
#                                     "EJ_PATH": "0",
#                                     "EJ_PATHNAME": "Not Ejected/Not Applicable",
#                                     "EMER_USE": "0",
#                                     "EMER_USENAME": "Not Applicable",
#                                     "EXTRICAT": "0",
#                                     "EXTRICATNAME": "Not Extricated or Not Applicable",
#                                     "FIRE_EXP": "0",
#                                     "FIRE_EXPNAME": "No or Not Reported",
#                                     "FUNC_SYS": null,
#                                     "FUNC_SYSNAME": null,
#                                     "HARM_EV": "12",
#                                     "HARM_EVNAME": "Motor Vehicle In-Transport ",
#                                     "HELM_MIS": null,
#                                     "HELM_MISNAME": null,
#                                     "HELM_USE": null,
#                                     "HELM_USENAME": null,
#                                     "HISPANIC": "0",
#                                     "HISPANICNAME": "Not A Fatality (not Applicable)",
#                                     "HOSPITAL": "0",
#                                     "HOSPITALNAME": "Not Transported",
#                                     "HOUR": "3",
#                                     "HOURNAME": "3:00am-3:59am",
#                                     "ICFINALBODY": null,
#                                     "ICFINALBODYNAME": null,
#                                     "IMPACT1": "12",
#                                     "IMPACT1NAME": "12 Clock Point",
#                                     "IMPACT2": null,
#                                     "IMPACT2NAME": null,
#                                     "INJ_SEV": "2",
#                                     "INJ_SEVNAME": "Suspected Minor Injury(B)",
#                                     "LAG_HRS": "999",
#                                     "LAG_HRSNAME": "Unknown",
#                                     "LAG_MINS": "99",
#                                     "LAG_MINSNAME": "Unknown",
#                                     "LOCATION": "0",
#                                     "LOCATIONNAME": "0",
#                                     "MAKE": "20",
#                                     "MAKENAME": "Chevrolet",
#                                     "MAK_MOD": "20037",
#                                     "MAK_MODNAME": "Chevrolet Malibu/Malibu Maxx",
#                                     "MAN_COLL": "6",
#                                     "MAN_COLLNAME": "Angle ",
#                                     "MINUTE": "7",
#                                     "MINUTENAME": "7",
#                                     "MOD_YEAR": "2004",
#                                     "MOD_YEARNAME": "2004",
#                                     "MONTH": "1",
#                                     "MonthName": "January",
#                                     "N_MOT_NO": null,
#                                     "OCCDrugs": [
#                                         {
#                                             "CaseYear": "2014",
#                                             "DRUGRES": "0",
#                                             "DRUGRESNAME": "Test Not Given",
#                                             "DRUGSPEC": "0",
#                                             "DRUGSPECNAME": "Test Not Given",
#                                             "PER_NO": "1",
#                                             "STATE": "1",
#                                             "STATEINITIAL": "AL",
#                                             "STATENAME": "Alabama",
#                                             "ST_CASE": "10003",
#                                             "VEH_NO": "1"
#                                         }
#                                     ],
#                                     "PER_NO": "1",
#                                     "PER_TYP": "1",
#                                     "PER_TYPNAME": "Driver of a Motor Vehicle In-Transport",
#                                     "P_SF1": "0",
#                                     "P_SF1NAME": "None",
#                                     "P_SF2": "0",
#                                     "P_SF2NAME": "None",
#                                     "P_SF3": "0",
#                                     "P_SF3NAME": "None",
#                                     "PersonRFs": [],
#                                     "RACE": "0",
#                                     "RACENAME": "Not a Fatality (not Applicable)",
#                                     "REST_MIS": "0",
#                                     "REST_MISNAME": "No",
#                                     "REST_USE": "7",
#                                     "REST_USENAME": "None Used",
#                                     "ROAD_FNC": "13",
#                                     "ROAD_FNCNAME": "Urban-Other Principal Arterial",
#                                     "ROLLOVER": "0",
#                                     "ROLLOVERNAME": "No Rollover",
#                                     "RUR_URB": null,
#                                     "RUR_URBNAME": null,
#                                     "Races": [],
#                                     "SCH_BUS": "0",
#                                     "SCH_BUSNAME": "No",
#                                     "SEAT_POS": "11",
#                                     "SEAT_POSNAME": "Front Seat, Left Side",
#                                     "SEX": "1",
#                                     "SEXNAME": "Male",
#                                     "SPEC_USE": "0",
#                                     "SPEC_USENAME": "No Special Use",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "STR_VEH": "0",
#                                     "STR_VEHNAME": "Occupant of a Motor Vehicle",
#                                     "ST_CASE": "10003",
#                                     "TOW_VEH": "0",
#                                     "TOW_VEHNAME": "No Trailing Units",
#                                     "VEH_NO": "1",
#                                     "VE_FORMS": "2",
#                                     "VPICBODYCLASS": null,
#                                     "VPICBODYCLASSNAME": null,
#                                     "VPICMAKE": null,
#                                     "VPICMAKENAME": null,
#                                     "VPICMODEL": null,
#                                     "VPICMODELNAME": null,
#                                     "WORK_INJ": "8",
#                                     "WORK_INJNAME": "Not Applicable (not a fatality)"
#                                 },
#                                 {
#                                     "AGE": "21",
#                                     "AGENAME": "21 Years",
#                                     "AIR_BAG": "1",
#                                     "AIR_BAGNAME": "Deployed- Front",
#                                     "ALC_DET": "9",
#                                     "ALC_DETNAME": "Not Reported",
#                                     "ALC_RES": "96",
#                                     "ALC_RESNAME": "Test Not Given",
#                                     "ALC_STATUS": "0",
#                                     "ALC_STATUSNAME": "Test Not Given",
#                                     "ATST_TYP": "0",
#                                     "ATST_TYPNAME": "Test Not Given",
#                                     "BODY_TYP": "4",
#                                     "BODY_TYPNAME": "4-door sedan, hardtop",
#                                     "CERT_NO": "************",
#                                     "COUNTY": "125",
#                                     "COUNTYNAME": "TUSCALOOSA (125)",
#                                     "CaseYear": "2014",
#                                     "DAY": "1",
#                                     "DEATH_DA": "88",
#                                     "DEATH_DANAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_HR": "88",
#                                     "DEATH_HRNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MN": "88",
#                                     "DEATH_MNNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MO": "88",
#                                     "DEATH_MONAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_TM": "8888",
#                                     "DEATH_TMNAME": "Not Applicable (Non-fatal",
#                                     "DEATH_YR": "8888",
#                                     "DEATH_YRNAME": "Not Applicable (Non-fatal)",
#                                     "DOA": "0",
#                                     "DOANAME": "Not Applicable",
#                                     "DRINKING": "8",
#                                     "DRINKINGNAME": "Not Reported",
#                                     "DRUGRES1": "0",
#                                     "DRUGRES1NAME": "Test Not Given",
#                                     "DRUGRES2": "0",
#                                     "DRUGRES2NAME": "Test Not Given",
#                                     "DRUGRES3": "0",
#                                     "DRUGRES3NAME": "Test Not Given",
#                                     "DRUGS": "8",
#                                     "DRUGSNAME": "Not Reported",
#                                     "DRUGTST1": "0",
#                                     "DRUGTST1NAME": "Test Not Given",
#                                     "DRUGTST2": "0",
#                                     "DRUGTST2NAME": "Test Not Given",
#                                     "DRUGTST3": "0",
#                                     "DRUGTST3NAME": "Test Not Given",
#                                     "DRUG_DET": "8",
#                                     "DRUG_DETNAME": "Not Reported",
#                                     "DSTATUS": "0",
#                                     "DSTATUSNAME": "Test Not Given",
#                                     "EJECTION": "0",
#                                     "EJECTIONNAME": "Not Ejected",
#                                     "EJ_PATH": "0",
#                                     "EJ_PATHNAME": "Not Ejected/Not Applicable",
#                                     "EMER_USE": "0",
#                                     "EMER_USENAME": "Not Applicable",
#                                     "EXTRICAT": "0",
#                                     "EXTRICATNAME": "Not Extricated or Not Applicable",
#                                     "FIRE_EXP": "0",
#                                     "FIRE_EXPNAME": "No or Not Reported",
#                                     "FUNC_SYS": null,
#                                     "FUNC_SYSNAME": null,
#                                     "HARM_EV": "12",
#                                     "HARM_EVNAME": "Motor Vehicle In-Transport ",
#                                     "HELM_MIS": null,
#                                     "HELM_MISNAME": null,
#                                     "HELM_USE": null,
#                                     "HELM_USENAME": null,
#                                     "HISPANIC": "0",
#                                     "HISPANICNAME": "Not A Fatality (not Applicable)",
#                                     "HOSPITAL": "0",
#                                     "HOSPITALNAME": "Not Transported",
#                                     "HOUR": "3",
#                                     "HOURNAME": "3:00am-3:59am",
#                                     "ICFINALBODY": null,
#                                     "ICFINALBODYNAME": null,
#                                     "IMPACT1": "12",
#                                     "IMPACT1NAME": "12 Clock Point",
#                                     "IMPACT2": null,
#                                     "IMPACT2NAME": null,
#                                     "INJ_SEV": "0",
#                                     "INJ_SEVNAME": "No Apparent Injury (O)",
#                                     "LAG_HRS": "999",
#                                     "LAG_HRSNAME": "Unknown",
#                                     "LAG_MINS": "99",
#                                     "LAG_MINSNAME": "Unknown",
#                                     "LOCATION": "0",
#                                     "LOCATIONNAME": "0",
#                                     "MAKE": "20",
#                                     "MAKENAME": "Chevrolet",
#                                     "MAK_MOD": "20037",
#                                     "MAK_MODNAME": "Chevrolet Malibu/Malibu Maxx",
#                                     "MAN_COLL": "6",
#                                     "MAN_COLLNAME": "Angle ",
#                                     "MINUTE": "7",
#                                     "MINUTENAME": "7",
#                                     "MOD_YEAR": "2004",
#                                     "MOD_YEARNAME": "2004",
#                                     "MONTH": "1",
#                                     "MonthName": "January",
#                                     "N_MOT_NO": null,
#                                     "OCCDrugs": [
#                                         {
#                                             "CaseYear": "2014",
#                                             "DRUGRES": "0",
#                                             "DRUGRESNAME": "Test Not Given",
#                                             "DRUGSPEC": "0",
#                                             "DRUGSPECNAME": "Test Not Given",
#                                             "PER_NO": "2",
#                                             "STATE": "1",
#                                             "STATEINITIAL": "AL",
#                                             "STATENAME": "Alabama",
#                                             "ST_CASE": "10003",
#                                             "VEH_NO": "1"
#                                         }
#                                     ],
#                                     "PER_NO": "2",
#                                     "PER_TYP": "2",
#                                     "PER_TYPNAME": "Passenger of a Motor Vehicle In-Transport",
#                                     "P_SF1": "0",
#                                     "P_SF1NAME": "None",
#                                     "P_SF2": "0",
#                                     "P_SF2NAME": "None",
#                                     "P_SF3": "0",
#                                     "P_SF3NAME": "None",
#                                     "PersonRFs": [],
#                                     "RACE": "0",
#                                     "RACENAME": "Not a Fatality (not Applicable)",
#                                     "REST_MIS": "0",
#                                     "REST_MISNAME": "No",
#                                     "REST_USE": "3",
#                                     "REST_USENAME": "Shoulder and Lap Belt Used",
#                                     "ROAD_FNC": "13",
#                                     "ROAD_FNCNAME": "Urban-Other Principal Arterial",
#                                     "ROLLOVER": "0",
#                                     "ROLLOVERNAME": "No Rollover",
#                                     "RUR_URB": null,
#                                     "RUR_URBNAME": null,
#                                     "Races": [],
#                                     "SCH_BUS": "0",
#                                     "SCH_BUSNAME": "No",
#                                     "SEAT_POS": "13",
#                                     "SEAT_POSNAME": "Front Seat, Right Side",
#                                     "SEX": "2",
#                                     "SEXNAME": "Female",
#                                     "SPEC_USE": "0",
#                                     "SPEC_USENAME": "No Special Use",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "STR_VEH": "0",
#                                     "STR_VEHNAME": "Occupant of a Motor Vehicle",
#                                     "ST_CASE": "10003",
#                                     "TOW_VEH": "0",
#                                     "TOW_VEHNAME": "No Trailing Units",
#                                     "VEH_NO": "1",
#                                     "VE_FORMS": "2",
#                                     "VPICBODYCLASS": null,
#                                     "VPICBODYCLASSNAME": null,
#                                     "VPICMAKE": null,
#                                     "VPICMAKENAME": null,
#                                     "VPICMODEL": null,
#                                     "VPICMODELNAME": null,
#                                     "WORK_INJ": "8",
#                                     "WORK_INJNAME": "Not Applicable (not a fatality)"
#                                 },
#                                 {
#                                     "AGE": "18",
#                                     "AGENAME": "18 Years",
#                                     "AIR_BAG": "0",
#                                     "AIR_BAGNAME": "Not Applicable",
#                                     "ALC_DET": "9",
#                                     "ALC_DETNAME": "Not Reported",
#                                     "ALC_RES": "96",
#                                     "ALC_RESNAME": "Test Not Given",
#                                     "ALC_STATUS": "0",
#                                     "ALC_STATUSNAME": "Test Not Given",
#                                     "ATST_TYP": "0",
#                                     "ATST_TYPNAME": "Test Not Given",
#                                     "BODY_TYP": "4",
#                                     "BODY_TYPNAME": "4-door sedan, hardtop",
#                                     "CERT_NO": "************",
#                                     "COUNTY": "125",
#                                     "COUNTYNAME": "TUSCALOOSA (125)",
#                                     "CaseYear": "2014",
#                                     "DAY": "1",
#                                     "DEATH_DA": "88",
#                                     "DEATH_DANAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_HR": "88",
#                                     "DEATH_HRNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MN": "88",
#                                     "DEATH_MNNAME": "Not Applicable (Non-fatal)",
#                                     "DEATH_MO": "88",
#                                     "DEATH_MONAME": "Not Applicable (Non-Fatal)",
#                                     "DEATH_TM": "8888",
#                                     "DEATH_TMNAME": "Not Applicable (Non-fatal",
#                                     "DEATH_YR": "8888",
#                                     "DEATH_YRNAME": "Not Applicable (Non-fatal)",
#                                     "DOA": "0",
#                                     "DOANAME": "Not Applicable",
#                                     "DRINKING": "8",
#                                     "DRINKINGNAME": "Not Reported",
#                                     "DRUGRES1": "0",
#                                     "DRUGRES1NAME": "Test Not Given",
#                                     "DRUGRES2": "0",
#                                     "DRUGRES2NAME": "Test Not Given",
#                                     "DRUGRES3": "0",
#                                     "DRUGRES3NAME": "Test Not Given",
#                                     "DRUGS": "8",
#                                     "DRUGSNAME": "Not Reported",
#                                     "DRUGTST1": "0",
#                                     "DRUGTST1NAME": "Test Not Given",
#                                     "DRUGTST2": "0",
#                                     "DRUGTST2NAME": "Test Not Given",
#                                     "DRUGTST3": "0",
#                                     "DRUGTST3NAME": "Test Not Given",
#                                     "DRUG_DET": "8",
#                                     "DRUG_DETNAME": "Not Reported",
#                                     "DSTATUS": "0",
#                                     "DSTATUSNAME": "Test Not Given",
#                                     "EJECTION": "0",
#                                     "EJECTIONNAME": "Not Ejected",
#                                     "EJ_PATH": "0",
#                                     "EJ_PATHNAME": "Not Ejected/Not Applicable",
#                                     "EMER_USE": "0",
#                                     "EMER_USENAME": "Not Applicable",
#                                     "EXTRICAT": "0",
#                                     "EXTRICATNAME": "Not Extricated or Not Applicable",
#                                     "FIRE_EXP": "0",
#                                     "FIRE_EXPNAME": "No or Not Reported",
#                                     "FUNC_SYS": null,
#                                     "FUNC_SYSNAME": null,
#                                     "HARM_EV": "12",
#                                     "HARM_EVNAME": "Motor Vehicle In-Transport ",
#                                     "HELM_MIS": null,
#                                     "HELM_MISNAME": null,
#                                     "HELM_USE": null,
#                                     "HELM_USENAME": null,
#                                     "HISPANIC": "0",
#                                     "HISPANICNAME": "Not A Fatality (not Applicable)",
#                                     "HOSPITAL": "0",
#                                     "HOSPITALNAME": "Not Transported",
#                                     "HOUR": "3",
#                                     "HOURNAME": "3:00am-3:59am",
#                                     "ICFINALBODY": null,
#                                     "ICFINALBODYNAME": null,
#                                     "IMPACT1": "12",
#                                     "IMPACT1NAME": "12 Clock Point",
#                                     "IMPACT2": null,
#                                     "IMPACT2NAME": null,
#                                     "INJ_SEV": "0",
#                                     "INJ_SEVNAME": "No Apparent Injury (O)",
#                                     "LAG_HRS": "999",
#                                     "LAG_HRSNAME": "Unknown",
#                                     "LAG_MINS": "99",
#                                     "LAG_MINSNAME": "Unknown",
#                                     "LOCATION": "0",
#                                     "LOCATIONNAME": "0",
#                                     "MAKE": "20",
#                                     "MAKENAME": "Chevrolet",
#                                     "MAK_MOD": "20037",
#                                     "MAK_MODNAME": "Chevrolet Malibu/Malibu Maxx",
#                                     "MAN_COLL": "6",
#                                     "MAN_COLLNAME": "Angle ",
#                                     "MINUTE": "7",
#                                     "MINUTENAME": "7",
#                                     "MOD_YEAR": "2004",
#                                     "MOD_YEARNAME": "2004",
#                                     "MONTH": "1",
#                                     "MonthName": "January",
#                                     "N_MOT_NO": null,
#                                     "OCCDrugs": [
#                                         {
#                                             "CaseYear": "2014",
#                                             "DRUGRES": "0",
#                                             "DRUGRESNAME": "Test Not Given",
#                                             "DRUGSPEC": "0",
#                                             "DRUGSPECNAME": "Test Not Given",
#                                             "PER_NO": "3",
#                                             "STATE": "1",
#                                             "STATEINITIAL": "AL",
#                                             "STATENAME": "Alabama",
#                                             "ST_CASE": "10003",
#                                             "VEH_NO": "1"
# ...
#                                     "AntilockBrakeSystem": null,
#                                     "AntilockBrakeSystemId": null,
#                                     "AutoPedestrianAlertingSound": null,
#                                     "AutoPedestrianAlertingSoundId": null,
#                                     "AutoReverseSystem": null,
#                                     "AutoReverseSystemId": null,
#                                     "AutomaticCrashNotification": null,
#                                     "AutomaticCrashNotificationId": null,
#                                     "AxleConfiguration": null,
#                                     "AxleConfigurationId": null,
#                                     "AxlesCount": null,
#                                     "BackupCamera": null,
#                                     "BackupCameraId": null,
#                                     "BasePrice": null,
#                                     "BatteryA_from": null,
#                                     "BatteryA_to": null,
#                                     "BatteryCellsPerModule": null,
#                                     "BatteryKWh_from": null,
#                                     "BatteryKWh_to": null,
#                                     "BatteryModulesPerPack": null,
#                                     "BatteryPacksPerVehicle": null,
#                                     "BatteryType": null,
#                                     "BatteryTypeId": null,
#                                     "BatteryV_from": null,
#                                     "BatteryV_to": null,
#                                     "BlindSpotIntervention": null,
#                                     "BlindSpotInterventionId": null,
#                                     "BlindSpotWarning": null,
#                                     "BlindSpotWarningId": null,
#                                     "BodyClass": "Sedan/Saloon",
#                                     "BodyClassId": "13",
#                                     "BrakeSystemDesc": null,
#                                     "BrakeSystemType": null,
#                                     "BrakeSystemTypeId": null,
#                                     "BusFloorConfigurationType": "Not Applicable",
#                                     "BusFloorConfigurationTypeId": "0",
#                                     "BusLengthFT": null,
#                                     "BusType": "Not Applicable",
#                                     "BusTypeId": "0",
#                                     "CASEYEAR": "2014",
#                                     "ChargerLevel": null,
#                                     "ChargerLevelId": null,
#                                     "ChargerPowerKW": null,
#                                     "CrashImminentBraking": null,
#                                     "CrashImminentBrakingId": null,
#                                     "CurbWeightLB": null,
#                                     "CustomMotorcycleType": "Not Applicable",
#                                     "CustomMotorcycleTypeId": "0",
#                                     "DaytimeRunningLight": null,
#                                     "DaytimeRunningLightId": null,
#                                     "DestinationMarket": null,
#                                     "DestinationMarketId": null,
#                                     "DisplacementCC": "3000",
#                                     "DisplacementCI": "183",
#                                     "DisplacementL": "3",
#                                     "DoorsCount": "4",
#                                     "DriveType": "4x2",
#                                     "DriveTypeId": "7",
#                                     "DynamicBrakeSupport": null,
#                                     "DynamicBrakeSupportId": null,
#                                     "EVDriveUnit": null,
#                                     "EVDriveUnitId": null,
#                                     "ElectronicStabilityControl": null,
#                                     "ElectronicStabilityControlId": null,
#                                     "EngineBrakeHP_from": "184",
#                                     "EngineBrakeHP_to": "217",
#                                     "EngineConfiguration": "V-Shaped",
#                                     "EngineConfigurationId": "2",
#                                     "EngineCoolingType": "Water",
#                                     "EngineCoolingTypeId": "2",
#                                     "EngineCylindersCount": "6",
#                                     "EngineElectrificationLevel": null,
#                                     "EngineElectrificationLevelId": null,
#                                     "EngineManufacturer": "Toyota",
#                                     "EngineModel": "1MZ-FE",
#                                     "EnginePowerKW": "137",
#                                     "EngineStrokeCycles": "4",
#                                     "EngineTurbo": null,
#                                     "EngineTurboId": null,
#                                     "EngineValveTrainDesign": null,
#                                     "EngineValveTrainDesignId": null,
#                                     "EntertainmentSystem": null,
#                                     "EntertainmentSystemId": null,
#                                     "EventDataRecorder": null,
#                                     "EventDataRecorderId": null,
#                                     "ForwardCollisionWarning": null,
#                                     "ForwardCollisionWarningId": null,
#                                     "FuelDeliveryInjectionType": null,
#                                     "FuelDeliveryInjectionTypeId": null,
#                                     "FuelTypePrimary": "Gasoline",
#                                     "FuelTypePrimaryId": "4",
#                                     "FuelTypeSecondary": null,
#                                     "FuelTypeSecondaryId": null,
#                                     "GrossCombWeightRatingFrom": null,
#                                     "GrossCombWeightRatingFromId": null,
#                                     "GrossCombWeightRatingTo": null,
#                                     "GrossCombWeightRatingToId": null,
#                                     "GrossVehicleWeightRatingFrom": null,
#                                     "GrossVehicleWeightRatingFromId": null,
#                                     "GrossVehicleWeightRatingTo": null,
#                                     "GrossVehicleWeightRatingToId": null,
#                                     "HeadlampLightSource": null,
#                                     "HeadlampLightSourceId": null,
#                                     "KeylessIgnition": null,
#                                     "KeylessIgnitionId": null,
#                                     "LaneCenteringAssistance": null,
#                                     "LaneCenteringAssistanceId": null,
#                                     "LaneDepartureWarning": null,
#                                     "LaneDepartureWarningId": null,
#                                     "LaneKeepingAssistance": null,
#                                     "LaneKeepingAssistanceId": null,
#                                     "Make": "TOYOTA",
#                                     "MakeId": "448",
#                                     "ManufacturerFullName": "TOYOTA MOTOR MANUFACTURING, KENTUCKY, INC.",
#                                     "ManufacturerFullNameId": "1088",
#                                     "Model": "Camry",
#                                     "ModelId": "2469",
#                                     "ModelYear": "1997",
#                                     "MotorcycleChassisType": "Not Applicable",
#                                     "MotorcycleChassisTypeId": "0",
#                                     "MotorcycleSuspensionType": "Not Applicable",
#                                     "MotorcycleSuspensionTypeId": "0",
#                                     "Note": null,
#                                     "OtherBatteryInfo": null,
#                                     "OtherBusInfo": null,
#                                     "OtherEngineInfo": null,
#                                     "OtherMotorcycleInfo": null,
#                                     "OtherRestraintSystemInfo": null,
#                                     "ParkAssist": null,
#                                     "ParkAssistId": null,
#                                     "PedestrianAutoEmergencyBraking": null,
#                                     "PedestrianAutoEmergencyBrakingId": null,
#                                     "PlantCity": null,
#                                     "PlantCompanyName": "Toyota Motor Manufacturing, Kentucky, Inc",
#                                     "PlantCountry": "UNITED STATES (USA)",
#                                     "PlantCountryId": "6",
#                                     "PlantState": "KENTUCKY",
#                                     "Pretensioner": null,
#                                     "PretensionerId": null,
#                                     "RearAutomaticEmergencyBraking": null,
#                                     "RearAutomaticEmergencyBrakingId": null,
#                                     "RearCrossTrafficAlert": null,
#                                     "RearCrossTrafficAlertId": null,
#                                     "SAEAutomationLevel_from": null,
#                                     "SAEAutomationLevel_to": null,
#                                     "STATE": "1",
#                                     "ST_CASE": "10003",
#                                     "SeatBeltType": "Manual",
#                                     "SeatBeltTypeId": "1",
#                                     "SeatRowsCount": null,
#                                     "SeatsCount": null,
#                                     "SemiAutoHeadlampBeamSwitching": null,
#                                     "SemiAutoHeadlampBeamSwitchingId": null,
#                                     "Series": "SXV20L/MCV20L",
#                                     "Series2": "",
#                                     "SteeringLocation": null,
#                                     "SteeringLocationId": null,
#                                     "TPMS": null,
#                                     "TPMSId": null,
#                                     "TopSpeedMPH": null,
#                                     "TrackWidthIN": null,
#                                     "TractionControl": null,
#                                     "TractionControlId": null,
#                                     "TransmissionSpeeds": null,
#                                     "TransmissionStyle": null,
#                                     "TransmissionStyleId": null,
#                                     "Trim": "",
#                                     "Trim2": "",
#                                     "TruckBedLengthIN": null,
#                                     "TruckBedType": "Not Applicable",
#                                     "TruckBedTypeId": "0",
#                                     "TruckBodyCabType": "Not Applicable",
#                                     "TruckBodyCabTypeId": "0",
#                                     "VEH_NO": "2",
#                                     "VINDecodeError": "0",
#                                     "VINDecodedOn": "3/25/2022 9:02:08 PM",
#                                     "VehicleDescriptor": "4T1BF22K*VU******",
#                                     "VehicleType": "PASSENGER CAR",
#                                     "VehicleTypeId": "2",
#                                     "WheelBaseIN_from": null,
#                                     "WheelBaseIN_to": null,
#                                     "WheelBaseType": null,
#                                     "WheelBaseTypeId": null,
#                                     "WheelSizeFrontIN": null,
#                                     "WheelSizeRearIN": null,
#                                     "WheelsCount": null,
#                                     "Windows": null
#                                 }
#                             ],
#                             "Violations": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "MVIOLATN": "0",
#                                     "MVIOLATNNAME": "None",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "2",
#                                     "VIOLATION": "0",
#                                     "VIOLATIONNAME": "None"
#                                 }
#                             ],
#                             "Visions": [
#                                 {
#                                     "CaseYear": "2014",
#                                     "MVISOBSC": "0",
#                                     "MVISOBSCNAME": "No Obstruction Noted",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "2",
#                                     "VISION": "0",
#                                     "VISIONNAME": "No Obstruction Noted"
#                                 }
#                             ],
#                             "Vsoes": [
#                                 {
#                                     "AOI": "55",
#                                     "AOINAME": "Non-Harmful Event",
#                                     "CASEYEAR": "2014",
#                                     "SOE": "63",
#                                     "SOENAME": "Ran Off Roadway - Right",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "2",
#                                     "VEVENTNUM": "2"
#                                 },
#                                 {
#                                     "AOI": "8",
#                                     "AOINAME": "8 Clock Point",
#                                     "CASEYEAR": "2014",
#                                     "SOE": "12",
#                                     "SOENAME": "Motor Vehicle In-Transport ",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "2",
#                                     "VEVENTNUM": "1"
#                                 },
#                                 {
#                                     "AOI": "98",
#                                     "AOINAME": "Not Reported",
#                                     "CASEYEAR": "2014",
#                                     "SOE": "30",
#                                     "SOENAME": "Utility Pole/Light Support",
#                                     "STATE": "1",
#                                     "STATENAME": "Alabama",
#                                     "ST_CASE": "10003",
#                                     "VEH_NO": "2",
#                                     "VEVENTNUM": "3"
#                                 }
#                             ]
#                         }
#                     ],
#                     "WEATHER": "1",
#                     "WEATHER1": "1",
#                     "WEATHER1NAME": "Clear",
#                     "WEATHER2": "0",
#                     "WEATHER2NAME": "No Additional Atmospheric Conditions",
#                     "WEATHERNAME": "Clear",
#                     "WRK_ZONE": "0",
#                     "WRK_ZONENAME": "None",
#                     "Weathers": null,
#                     "YEAR": "2014"
#                 }
#             }
#         ]
#     ],
#     "SearchCriteria": "StateCase: 10003 And CaseYear: 2014 And State: 1"
# }
